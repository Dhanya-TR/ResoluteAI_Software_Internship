# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanya-TR/ResoluteAI_Software_Internship/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
vid=cv2.VideoCapture(0)

while(True):
    ret,frame=vid.read()
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
vid.release()
cv2.destroyAllWindows()   
#intro

# %%
# !pip install opencv-python

# %%
import cv2

# %%
import cv2
import numpy as np
vid=cv2.VideoCapture(0)

while(True):
    ret,frame=vid.read()
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
vid.release()
cv2.destroyAllWindows()
#loading video

# %%
import numpy as np
import cv2

img = cv2.imread('C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.05.29 AM.jpeg',cv2.IMREAD_COLOR)
cv2.line(img,(0,0),(200,300),(255,255,255),50)
cv2.rectangle(img,(500,250),(1000,500),(0,0,255),15)
cv2.circle(img,(447,63), 63, (0,255,0), -1)
pts = np.array([[100,50],[200,300],[700,200],[500,100]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img, [pts], True, (0,255,255), 3)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'OpenCV Tuts!',(10,500), font, 6, (200,255,155), 13, cv2.LINE_AA)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
#drawing and writing on image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.05.29 AM.jpeg')
newimg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(newimg)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.05.29 AM.jpeg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap='gray',interpolation='bicubic')
plt.show()

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.05.29 AM.jpeg',cv2.IMREAD_COLOR)
px = img[55,55]

img[55,55] = [255,255,255]

px = img[55,55] 
print(px)

px = img[100:150,100:150] 
print(px)

img[100:150,100:150] = [255,255,255]
print(img.shape) 
print(img.size) 
print(img.dtype)
watch_face = img[37:111,107:194] 
img[0:74,0:87] = watch_face 
cv2.imshow('image',img) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
#image operations
# Out:
# [255 255 255]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# (1147, 1080, 3)
# 3716280
# uint8

# %%
import cv2
img1 = cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg")
img2 = cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg")
add = img1 + img2
sub = img1 - img2
add1 = cv2.add(img1 ,img2)
cv2.imshow("addition",add)
cv2.imshow("subtraction",sub)
cv2.imshow("addition1",add1)
cv2.waitKey(0)
cv2.destroyAllWindows()
#image arithmetics and logic

# %%
import cv2
import matplotlib.pyplot as plt
pic= cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg",0)
plt.imshow(pic,cmap="gray")

# %%
import cv2
import numpy as np

img = cv2.imread('C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg')
retval, threshold = cv2.threshold(img, 12, 255, cv2.THRESH_BINARY)
cv2.imshow('original',img)
cv2.imshow('threshold',threshold)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
pic= cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg",0)
ret,th=cv2.threshold(pic,127,255,cv2.THRESH_BINARY)
plt.imshow(th,cmap="gray")
#threshold

# %%
import cv2
import matplotlib.pyplot as plt
pic= cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg",0)
th=cv2.adaptiveThreshold(pic,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,5,1)
plt.imshow(th,cmap="gray")
#adaptive threshold

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()
#color filtering

# %%
import cv2 
import numpy as np
cap = cv2.VideoCapture(0)
while(1): 
    _, frame = cap.read() 
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV) 
    lower_red = np.array([30,150,50]) 
    upper_red = np.array([255,255,180]) 
    mask = cv2.inRange(hsv, lower_red, upper_red) 
    res = cv2.bitwise_and(frame,frame, mask= mask)
    kernel = np.ones((15,15),np.float32)/225 
    smoothed = cv2.filter2D(res,-1,kernel) 
    cv2.imshow('Original',frame) 
    cv2.imshow('Averaging',smoothed) 
    k = cv2.waitKey(5) & 0xFF 
    if k == 27: 
        break 
cv2.destroyAllWindows() 
cap.release()
#blurring and smoothing

# %%
import cv2
import numpy as np
image=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg",0)
kernel=np.ones((5,5),np.uint0)
ersoion=cv2.erode(image,kernel,iterations=1)
cv2.imshow("original",image)
cv2.imshow("erosion",ersoion)
cv2.waitKey(0)
cv2.destroyAllWindows()
#morphological Transformation

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    kernel = np.ones((5,5),np.uint8)
    erosion = cv2.erode(mask,kernel,iterations = 1)
    dilation = cv2.dilate(mask,kernel,iterations = 1)

    cv2.imshow('Original',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('Erosion',erosion)
    cv2.imshow('Dilation',dilation)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()
#morphological transformation

# %%
#canny edge detection
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

   
    _, frame = cap.read()
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    lower_red = np.array([30,150,50])
    upper_red = np.array([255,255,180])
    
    mask = cv2.inRange(hsv, lower_red, upper_red)
    res = cv2.bitwise_and(frame,frame, mask= mask)

    laplacian = cv2.Laplacian(frame,cv2.CV_64F)
    sobelx = cv2.Sobel(frame,cv2.CV_64F,1,0,ksize=5)
    sobely = cv2.Sobel(frame,cv2.CV_64F,0,1,ksize=5)

    cv2.imshow('Original',frame)
    cv2.imshow('Mask',mask)
    cv2.imshow('laplacian',laplacian)
    cv2.imshow('sobelx',sobelx)
    cv2.imshow('sobely',sobely)

    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()

# %%
import cv2
image=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.49.28 PM.jpeg")
cv2.imwrite('Canny.jpeg',cv2.Canny(image,200,300))
cv2.imshow('Canny',cv2.imread('Canny.jpeg'))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
or_img=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.05.29 AM.jpeg",1)
or_gray_img=cv2.cvtColor(or_img,cv2.COLOR_BGR2GRAY)
template=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-31 at 10.01.51 PM.jpeg",0)
w,h=template.shape[::-1]
res=cv2.matchTemplate(or_gray_img,template,cv2.TM_CCOEFF_NORMED)
th=0.8
loc=np.where(res>=th)
for pt in zip(*loc[::-1]):
    cv2.rectangle(or_img,pt,(pt[0]+w,pt[1]+h),(0,255,200),1)

cv2.imshow("watch dial found",or_img)
key=cv2.waitKey(0)
if key==81:
    exit
#template matching

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-30 at 9.05.29 AM.jpeg")
mask=np.zeros(img.shape[:2],np.uint8)
bdgModel=np.zeros((1,65),np.float64)
fdgModel=np.zeros((1,65),np.float64)
rect=(50,50,800,500)
cv2.grabCut(img,mask,rect,bdgModel,fdgModel,5,cv2.GC_INIT_WITH_RECT)
mask2=np.where((mask==2)|(mask==0),0,1).astype('uint8')
img=img*mask2[:,:,np.newaxis]
plt.imshow(img)
plt.colorbar()
plt.show()
#grabcut foreground extraction

# %%
import cv2 as cv
import numpy as np
img=cv.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-31 at 10.52.52 PM.jpeg")
gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
corners=cv.goodFeaturesToTrack(gray,50,0.01,10)
corners=np.int0(corners)
for i in corners:
    x,y=i.ravel()
    cv.circle(img,(x,y),3,255,-1)
cv.imshow('dat',img)
if cv.waitKey(0) & 0xFF==27:
    cv.destroyAllWindows()
#corner detection

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img1=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-31 at 11.14.49 PM.jpeg",1)
img2=cv2.imread("C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-31 at 11.25.13 PM.jpeg",1)
orb=cv2.ORB_create()
kp1,des1=orb.detectAndCompute(img1,None)
kp2,des2=orb.detectAndCompute(img2,None)
bf=cv2.BFMatcher(cv2.NORM_HAMMING,crossCheck=True)
matches=bf.match(des1,des2)
matches=sorted(matches,key=lambda x:x.distance)
img3=cv2.drawMatches(img1,kp1,img2,kp2,matches[:30],None,flags=2)
plt.imshow(img3)
plt.show()
#feature matching(homography) brute force

# %%
import numpy as np 
import cv2 
face_cascade = cv2.CascadeClassifier('C:\\Users\\LENOVO\\anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml') 
eye_cascade = cv2.CascadeClassifier('C:\\Users\\LENOVO\\anaconda3\\Lib\\site-packages\\cv2\\data\\haarcascade_eye.xml') 
cap = cv2.VideoCapture(0) 
while 1: 
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces: 
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w] 
        roi_color = img[y:y+h, x:x+w] 
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes: 
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    cv2.imshow('img',img) 
    k = cv2.waitKey(30) & 0xff 
    if k == 27: 
        break 
cap.release() 
cv2.destroyAllWindows()
#haar cascade object detection face and eye

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture("C:\\Users\\LENOVO\\Downloads\\walkingpeople.mp4")
fgbg = cv2.createBackgroundSubtractorMOG2()

while(1):
    ret, frame = cap.read()

    fgmask = fgbg.apply(frame)
 
    cv2.imshow('fgmask',frame)
    cv2.imshow('frame',fgmask)

    
    k = cv2.waitKey(30) & 0xff
    if k == 27:
        break
    

cap.release()
cv2.destroyAllWindows()
#mog background reduction

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
 
img1 = cv2.imread('C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-31 at 11.14.49 PM.jpeg')
img2 = cv2.imread('C:\\Users\\LENOVO\\Downloads\\WhatsApp Image 2023-05-31 at 11.25.13 PM.jpeg') 
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols ] 
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 220, 255, cv2.THRESH_BINARY_INV) 
mask_inv = cv2.bitwise_not(mask) 
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)
dst = cv2.add(img1_bg,img2_fg) 
img1[0:rows, 0:cols ] = dst
cv2.imshow('res',img1) 
cv2.waitKey(0) 
cv2.destroyAllWindows()
#logo

# %%
import cv2
cap=cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier('C:\\Users\\LENOVO\\Downloads\\custom haar cascade\\rasberry.xml')
while(True):
    ret,frame=cap.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(gray,1.3,5)
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF==('q'):
        break
cap.release()
cv2.destroyAllWindows()
#our own haar cascade
